# %% [markdown]
# ### 1.包导入

# %%
import gym
import torch as T
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical
import numpy as np
import pickle
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2.环境尝试

# %%
env = gym.make("CartPole-v1")
env.reset()
env.step(0)
# Out:
# (array([ 0.02709634, -0.22496942, -0.04320554,  0.29551566], dtype=float32),
#  1.0,
#  False,
#  False,
#  {})

# %% [markdown]
# ### 3.定义 Actor 网络

# %%
# 定义策略网络
class ActorNetwork(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(ActorNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.device = T.device("cuda" if T.cuda.is_available() else "cpu")
        self.to(self.device)

    def forward(self, x):
        x = T.tensor(x, dtype=T.float32).to(self.device)
        layer1 = T.relu(self.fc1(x))
        layer2 = T.relu(self.fc2(layer1))
        p = T.softmax(self.fc3(layer2), dim=-1)
        return p

# %% [markdown]
# ### 4. 定义 Critic 网络

# %%
class Critic(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 1)
        self.device = T.device("cuda" if T.cuda.is_available() else "cpu")
        self.to(self.device)

    def forward(self, x):
        x = T.tensor(x, dtype=T.float32).to(self.device)
        layer1 = T.relu(self.fc1(x))
        layer2 = T.relu(self.fc2(layer1))
        value = self.fc3(layer2)
        return value

# %% [markdown]
# ### 5.设置环境和超参数

# %%
# 设置环境
env = gym.make("CartPole-v1")
input_dim = env.observation_space.shape[0]  # 输入维度
hidden_dim = 512
output_dim = env.action_space.n  # 输出维度
# 设置超参数
batch_size = 10  # 设置每次更新的轨迹数量
gamma = 0.9  # 奖励折扣因子
avg_episode = 50
save_episode = 200
print_episode = 50
clip_norm = 100
continue_train = True
num_episodes = 20000
learning_rate = 1e-4

# 学习进度保存路径
actor_model_path = "./save/s11_actor_net.pth"
critic_model_path = "./save/s11_critic_net.pth"
avg_path = "./save/s11_avg_rewards.pth"

# %%
actor_net = ActorNetwork(input_dim, hidden_dim, output_dim)
critic_net = Critic(input_dim, hidden_dim)
actor_optimizer = optim.AdamW(actor_net.parameters(), lr=learning_rate)
critic_optimizer = optim.AdamW(critic_net.parameters(), lr=learning_rate)
avg_rewards = []

if continue_train:
    if os.path.exists(actor_model_path) and os.path.exists(critic_model_path) and os.path.exists(avg_path):
        actor_net.load_state_dict(T.load(actor_model_path))
        actor_net.to(actor_net.device)
        critic_net.load_state_dict(T.load(critic_model_path))
        critic_net.to(critic_net.device)
        with open(avg_path, "rb") as f:
            avg_rewards = pickle.load(f)
len(avg_rewards)
# Out:
# /tmp/ipykernel_89963/800411927.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   actor_net.load_state_dict(T.load(actor_model_path))
# /tmp/ipykernel_89963/800411927.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   critic_net.load_state_dict(T.load(critic_model_path))
# 100

# %% [markdown]
# ### 6.开始训练

# %%
# 开始训练
record_rewards = []
for episode in range(1, num_episodes + 1):
    total_reward = []
    episode_reward = 0
    state = env.reset()[0]


    for _ in range(1000):# 设置最大步长
        probs = actor_net(state)
        m = Categorical(probs)
        action = m.sample()
        next_state, reward, terminated, truncated, info = env.step(action.item())

        done = bool(terminated) or bool(truncated)

        episode_reward += reward

        # Critic 估计当前状态值
        value = critic_net(state)
        next_state_value = critic_net(next_state)

        # 计算 TD 误差和优势，如果终止，则忽略下一状态
        if not done:
            td_target = reward + gamma * next_state_value
        elif truncated:
            td_target = reward + reward / (1-gamma) # 如果截断，则用无限奖励的折现代表下一状态的值
        else:
            td_target = reward # 如果死亡，则没有下一状态的值

        td_error = td_target - value

        # Critic 网络更新
        critic_loss = td_error.pow(2)/batch_size
        critic_loss.backward()  

        # Actor 网络更新
        actor_loss = -m.log_prob(action) * td_error.detach()/batch_size # 用detach()切断梯度,避免actor网络更新影响Critic网络更新    
        actor_loss.backward()

        if done:
            break
        else:
            state = next_state

    if episode % batch_size == 0: 
        critic_optimizer.step()
        actor_optimizer.step()
        critic_optimizer.zero_grad()
        actor_optimizer.zero_grad()


    record_rewards.append(episode_reward)

    # 输出训练进度
    if episode % avg_episode == 0:
        avg_reward = sum(record_rewards[-avg_episode:]) / avg_episode
        avg_rewards.append(avg_reward)
        if episode % print_episode == 0:
            print(
                f"Episode {episode}, Current Reward:{record_rewards[-1]}, Avg Reward: {avg_reward}"
            )
        if episode % save_episode == 0:
            print(f"to save model and avg_rewards {len(avg_rewards)}")
            T.save(actor_net.state_dict(), actor_model_path)
            T.save(critic_net.state_dict(), critic_model_path)
            with open(avg_path, "wb") as f:
                pickle.dump(avg_rewards, f)
# Out:
# Episode 50, Current Reward:500.0, Avg Reward: 262.46
# Episode 100, Current Reward:306.0, Avg Reward: 280.96
# Episode 150, Current Reward:221.0, Avg Reward: 315.52
# Episode 200, Current Reward:500.0, Avg Reward: 302.1
# to save model and avg_rewards 104
# Episode 250, Current Reward:256.0, Avg Reward: 265.52
# Episode 300, Current Reward:337.0, Avg Reward: 280.84
# Episode 350, Current Reward:213.0, Avg Reward: 274.22
# Episode 400, Current Reward:346.0, Avg Reward: 259.56
# to save model and avg_rewards 108
# Episode 450, Current Reward:340.0, Avg Reward: 301.9
# Episode 500, Current Reward:226.0, Avg Reward: 284.3
# Episode 550, Current Reward:300.0, Avg Reward: 317.32
# Episode 600, Current Reward:425.0, Avg Reward: 340.16
# to save model and avg_rewards 112
# Episode 650, Current Reward:500.0, Avg Reward: 339.64
# Episode 700, Current Reward:249.0, Avg Reward: 344.54
# Episode 750, Current Reward:300.0, Avg Reward: 308.42
# Episode 800, Current Reward:276.0, Avg Reward: 302.26
# to save model and avg_rewards 116
# Episode 850, Current Reward:290.0, Avg Reward: 298.54
# Episode 900, Current Reward:265.0, Avg Reward: 321.88
# Episode 950, Current Reward:284.0, Avg Reward: 295.02
# Episode 1000, Current Reward:319.0, Avg Reward: 317.52
# to save model and avg_rewards 120
# Episode 1050, Current Reward:254.0, Avg Reward: 359.54
# Episode 1100, Current Reward:329.0, Avg Reward: 335.1
# Episode 1150, Current Reward:318.0, Avg Reward: 372.22
# Episode 1200, Current Reward:500.0, Avg Reward: 364.84
# to save model and avg_rewards 124
# Episode 1250, Current Reward:277.0, Avg Reward: 377.54
# Episode 1300, Current Reward:369.0, Avg Reward: 341.5
# Episode 1350, Current Reward:466.0, Avg Reward: 317.5
# Episode 1400, Current Reward:323.0, Avg Reward: 387.44
# to save model and avg_rewards 128
# Episode 1450, Current Reward:316.0, Avg Reward: 346.86
# Episode 1500, Current Reward:360.0, Avg Reward: 364.3
# Episode 1550, Current Reward:281.0, Avg Reward: 375.96
# Episode 1600, Current Reward:380.0, Avg Reward: 384.54
# to save model and avg_rewards 132
# Episode 1650, Current Reward:447.0, Avg Reward: 387.44
# Episode 1700, Current Reward:378.0, Avg Reward: 405.24
# Episode 1750, Current Reward:386.0, Avg Reward: 378.42
# Episode 1800, Current Reward:500.0, Avg Reward: 435.32
# to save model and avg_rewards 136
# Episode 1850, Current Reward:289.0, Avg Reward: 399.78
# Episode 1900, Current Reward:334.0, Avg Reward: 373.78
# Episode 1950, Current Reward:420.0, Avg Reward: 380.52
# Episode 2000, Current Reward:492.0, Avg Reward: 399.22
# to save model and avg_rewards 140
# Episode 2050, Current Reward:367.0, Avg Reward: 408.1
# Episode 2100, Current Reward:431.0, Avg Reward: 450.26
# Episode 2150, Current Reward:347.0, Avg Reward: 428.52
# Episode 2200, Current Reward:500.0, Avg Reward: 453.28
# to save model and avg_rewards 144
# Episode 2250, Current Reward:500.0, Avg Reward: 439.7
# Episode 2300, Current Reward:500.0, Avg Reward: 456.54
# Episode 2350, Current Reward:500.0, Avg Reward: 481.86
# Episode 2400, Current Reward:500.0, Avg Reward: 471.46
# to save model and avg_rewards 148
# Episode 2450, Current Reward:377.0, Avg Reward: 413.0
# Episode 2500, Current Reward:208.0, Avg Reward: 249.02
# Episode 2550, Current Reward:131.0, Avg Reward: 159.94
# Episode 2600, Current Reward:139.0, Avg Reward: 131.02
# to save model and avg_rewards 152
# Episode 2650, Current Reward:169.0, Avg Reward: 148.28
# Episode 2700, Current Reward:172.0, Avg Reward: 175.56
# Episode 2750, Current Reward:150.0, Avg Reward: 166.04
# Episode 2800, Current Reward:160.0, Avg Reward: 145.98
# to save model and avg_rewards 156
# Episode 2850, Current Reward:157.0, Avg Reward: 142.0
# Episode 2900, Current Reward:133.0, Avg Reward: 151.7
# Episode 2950, Current Reward:153.0, Avg Reward: 154.32
# Episode 3000, Current Reward:154.0, Avg Reward: 151.66
# to save model and avg_rewards 160
# Episode 3050, Current Reward:141.0, Avg Reward: 147.4
# Episode 3100, Current Reward:153.0, Avg Reward: 146.64
# Episode 3150, Current Reward:141.0, Avg Reward: 144.08
# Episode 3200, Current Reward:152.0, Avg Reward: 144.42
# to save model and avg_rewards 164
# Episode 3250, Current Reward:161.0, Avg Reward: 142.28
# Episode 3300, Current Reward:125.0, Avg Reward: 144.76
# Episode 3350, Current Reward:136.0, Avg Reward: 140.52
# Episode 3400, Current Reward:127.0, Avg Reward: 133.96
# to save model and avg_rewards 168
# Episode 3450, Current Reward:134.0, Avg Reward: 132.48
# Episode 3500, Current Reward:110.0, Avg Reward: 131.38
# Episode 3550, Current Reward:120.0, Avg Reward: 130.72
# Episode 3600, Current Reward:130.0, Avg Reward: 133.84
# to save model and avg_rewards 172
# Episode 3650, Current Reward:149.0, Avg Reward: 136.42
# Episode 3700, Current Reward:130.0, Avg Reward: 142.2
# Episode 3750, Current Reward:136.0, Avg Reward: 141.02
# Episode 3800, Current Reward:147.0, Avg Reward: 137.28
# to save model and avg_rewards 176
# Episode 3850, Current Reward:134.0, Avg Reward: 138.6
# Episode 3900, Current Reward:142.0, Avg Reward: 137.54
# Episode 3950, Current Reward:125.0, Avg Reward: 136.78
# Episode 4000, Current Reward:122.0, Avg Reward: 137.72
# to save model and avg_rewards 180
# Episode 4050, Current Reward:132.0, Avg Reward: 137.38
# Episode 4100, Current Reward:137.0, Avg Reward: 135.12
# Episode 4150, Current Reward:124.0, Avg Reward: 133.86
# Episode 4200, Current Reward:137.0, Avg Reward: 136.84
# to save model and avg_rewards 184
# Episode 4250, Current Reward:139.0, Avg Reward: 137.48
# Episode 4300, Current Reward:137.0, Avg Reward: 141.86
# Episode 4350, Current Reward:145.0, Avg Reward: 140.18
# Episode 4400, Current Reward:137.0, Avg Reward: 135.96
# to save model and avg_rewards 188
# Episode 4450, Current Reward:139.0, Avg Reward: 138.78
# Episode 4500, Current Reward:154.0, Avg Reward: 135.46
# Episode 4550, Current Reward:144.0, Avg Reward: 136.0
# Episode 4600, Current Reward:136.0, Avg Reward: 136.6
# to save model and avg_rewards 192
# Episode 4650, Current Reward:124.0, Avg Reward: 137.12
# Episode 4700, Current Reward:139.0, Avg Reward: 137.54
# Episode 4750, Current Reward:115.0, Avg Reward: 136.72
# Episode 4800, Current Reward:157.0, Avg Reward: 139.62
# to save model and avg_rewards 196
# Episode 4850, Current Reward:132.0, Avg Reward: 141.14
# Episode 4900, Current Reward:162.0, Avg Reward: 139.94
# Episode 4950, Current Reward:135.0, Avg Reward: 138.66
# Episode 5000, Current Reward:148.0, Avg Reward: 140.7
# to save model and avg_rewards 200
# Episode 5050, Current Reward:130.0, Avg Reward: 137.54
# Episode 5100, Current Reward:158.0, Avg Reward: 144.72
# Episode 5150, Current Reward:164.0, Avg Reward: 142.56
# Episode 5200, Current Reward:141.0, Avg Reward: 138.32
# to save model and avg_rewards 204
# Episode 5250, Current Reward:132.0, Avg Reward: 137.68
# Episode 5300, Current Reward:136.0, Avg Reward: 137.76
# Episode 5350, Current Reward:145.0, Avg Reward: 136.1
# Episode 5400, Current Reward:136.0, Avg Reward: 138.62
# to save model and avg_rewards 208
# Episode 5450, Current Reward:126.0, Avg Reward: 138.52
# Episode 5500, Current Reward:134.0, Avg Reward: 137.24
# Episode 5550, Current Reward:132.0, Avg Reward: 136.62
# Episode 5600, Current Reward:135.0, Avg Reward: 136.26
# to save model and avg_rewards 212
# Episode 5650, Current Reward:149.0, Avg Reward: 137.66
# Episode 5700, Current Reward:143.0, Avg Reward: 137.24
# Episode 5750, Current Reward:157.0, Avg Reward: 137.38
# Episode 5800, Current Reward:138.0, Avg Reward: 140.48
# to save model and avg_rewards 216
# Episode 5850, Current Reward:126.0, Avg Reward: 139.76
# Episode 5900, Current Reward:154.0, Avg Reward: 143.08
# Episode 5950, Current Reward:129.0, Avg Reward: 145.12
# Episode 6000, Current Reward:172.0, Avg Reward: 146.88
# to save model and avg_rewards 220
# Episode 6050, Current Reward:153.0, Avg Reward: 141.68
# Episode 6100, Current Reward:169.0, Avg Reward: 143.88
# Episode 6150, Current Reward:135.0, Avg Reward: 145.74
# Episode 6200, Current Reward:159.0, Avg Reward: 143.74
# to save model and avg_rewards 224
# Episode 6250, Current Reward:145.0, Avg Reward: 145.44
# Episode 6300, Current Reward:146.0, Avg Reward: 145.76
# Episode 6350, Current Reward:150.0, Avg Reward: 139.88
# Episode 6400, Current Reward:131.0, Avg Reward: 148.54
# to save model and avg_rewards 228
# Episode 6450, Current Reward:150.0, Avg Reward: 152.8
# Episode 6500, Current Reward:123.0, Avg Reward: 148.76
# Episode 6550, Current Reward:149.0, Avg Reward: 145.34
# Episode 6600, Current Reward:132.0, Avg Reward: 147.22
# to save model and avg_rewards 232
# Episode 6650, Current Reward:146.0, Avg Reward: 150.5
# Episode 6700, Current Reward:161.0, Avg Reward: 147.68
# Episode 6750, Current Reward:167.0, Avg Reward: 149.24
# Episode 6800, Current Reward:138.0, Avg Reward: 148.28
# to save model and avg_rewards 236
# Episode 6850, Current Reward:141.0, Avg Reward: 152.08
# Episode 6900, Current Reward:161.0, Avg Reward: 153.3
# Episode 6950, Current Reward:165.0, Avg Reward: 152.98
# Episode 7000, Current Reward:182.0, Avg Reward: 148.34
# to save model and avg_rewards 240
# Episode 7050, Current Reward:154.0, Avg Reward: 150.04
# Episode 7100, Current Reward:155.0, Avg Reward: 150.04
# Episode 7150, Current Reward:126.0, Avg Reward: 151.56
# Episode 7200, Current Reward:139.0, Avg Reward: 150.26
# to save model and avg_rewards 244
# Episode 7250, Current Reward:136.0, Avg Reward: 149.14
# Episode 7300, Current Reward:157.0, Avg Reward: 146.92
# Episode 7350, Current Reward:150.0, Avg Reward: 156.46
# Episode 7400, Current Reward:161.0, Avg Reward: 153.88
# to save model and avg_rewards 248
# Episode 7450, Current Reward:159.0, Avg Reward: 154.82
# Episode 7500, Current Reward:169.0, Avg Reward: 157.86
# Episode 7550, Current Reward:171.0, Avg Reward: 155.66
# Episode 7600, Current Reward:160.0, Avg Reward: 157.34
# to save model and avg_rewards 252
# Episode 7650, Current Reward:165.0, Avg Reward: 159.36
# Episode 7700, Current Reward:177.0, Avg Reward: 156.22
# Episode 7750, Current Reward:147.0, Avg Reward: 154.42
# Episode 7800, Current Reward:158.0, Avg Reward: 159.2
# to save model and avg_rewards 256
# Episode 7850, Current Reward:162.0, Avg Reward: 159.64
# Episode 7900, Current Reward:151.0, Avg Reward: 164.32
# Episode 7950, Current Reward:152.0, Avg Reward: 160.22
# Episode 8000, Current Reward:163.0, Avg Reward: 163.66
# to save model and avg_rewards 260
# Episode 8050, Current Reward:151.0, Avg Reward: 160.88
# Episode 8100, Current Reward:190.0, Avg Reward: 165.78
# Episode 8150, Current Reward:195.0, Avg Reward: 167.84
# Episode 8200, Current Reward:177.0, Avg Reward: 164.34
# to save model and avg_rewards 264
# Episode 8250, Current Reward:195.0, Avg Reward: 162.86
# Episode 8300, Current Reward:145.0, Avg Reward: 159.88
# Episode 8350, Current Reward:183.0, Avg Reward: 156.72
# Episode 8400, Current Reward:150.0, Avg Reward: 155.56
# to save model and avg_rewards 268
# Episode 8450, Current Reward:150.0, Avg Reward: 162.2
# Episode 8500, Current Reward:181.0, Avg Reward: 160.06
# Episode 8550, Current Reward:142.0, Avg Reward: 154.88
# Episode 8600, Current Reward:186.0, Avg Reward: 155.98
# to save model and avg_rewards 272
# Episode 8650, Current Reward:163.0, Avg Reward: 157.38
# Episode 8700, Current Reward:152.0, Avg Reward: 159.04
# Episode 8750, Current Reward:158.0, Avg Reward: 162.48
# Episode 8800, Current Reward:155.0, Avg Reward: 161.8
# to save model and avg_rewards 276
# Episode 8850, Current Reward:223.0, Avg Reward: 165.68
# Episode 8900, Current Reward:156.0, Avg Reward: 167.28
# Episode 8950, Current Reward:160.0, Avg Reward: 167.5
# Episode 9000, Current Reward:169.0, Avg Reward: 166.6
# to save model and avg_rewards 280
# Episode 9050, Current Reward:141.0, Avg Reward: 165.42
# Episode 9100, Current Reward:158.0, Avg Reward: 169.78
# Episode 9150, Current Reward:211.0, Avg Reward: 165.12
# Episode 9200, Current Reward:173.0, Avg Reward: 172.7
# to save model and avg_rewards 284
# Episode 9250, Current Reward:155.0, Avg Reward: 171.04
# Episode 9300, Current Reward:179.0, Avg Reward: 171.82
# Episode 9350, Current Reward:146.0, Avg Reward: 168.04
# Episode 9400, Current Reward:153.0, Avg Reward: 172.08
# to save model and avg_rewards 288
# Episode 9450, Current Reward:182.0, Avg Reward: 169.94
# Episode 9500, Current Reward:168.0, Avg Reward: 164.4
# Episode 9550, Current Reward:195.0, Avg Reward: 175.96
# Episode 9600, Current Reward:193.0, Avg Reward: 179.08
# to save model and avg_rewards 292
# Episode 9650, Current Reward:179.0, Avg Reward: 181.88
# Episode 9700, Current Reward:156.0, Avg Reward: 179.28
# Episode 9750, Current Reward:174.0, Avg Reward: 181.34
# Episode 9800, Current Reward:202.0, Avg Reward: 192.5
# to save model and avg_rewards 296
# Episode 9850, Current Reward:153.0, Avg Reward: 181.66
# Episode 9900, Current Reward:187.0, Avg Reward: 187.44
# Episode 9950, Current Reward:186.0, Avg Reward: 187.42
# Episode 10000, Current Reward:177.0, Avg Reward: 189.42
# to save model and avg_rewards 300
# Episode 10050, Current Reward:179.0, Avg Reward: 188.04
# Episode 10100, Current Reward:186.0, Avg Reward: 183.56
# Episode 10150, Current Reward:190.0, Avg Reward: 179.78
# Episode 10200, Current Reward:242.0, Avg Reward: 200.68
# to save model and avg_rewards 304
# Episode 10250, Current Reward:219.0, Avg Reward: 200.22
# Episode 10300, Current Reward:171.0, Avg Reward: 193.18
# Episode 10350, Current Reward:180.0, Avg Reward: 187.18
# Episode 10400, Current Reward:222.0, Avg Reward: 201.92
# to save model and avg_rewards 308
# Episode 10450, Current Reward:342.0, Avg Reward: 203.7
# Episode 10500, Current Reward:260.0, Avg Reward: 202.92
# Episode 10550, Current Reward:194.0, Avg Reward: 220.92
# Episode 10600, Current Reward:214.0, Avg Reward: 206.2
# to save model and avg_rewards 312
# Episode 10650, Current Reward:255.0, Avg Reward: 203.12
# Episode 10700, Current Reward:199.0, Avg Reward: 220.98
# Episode 10750, Current Reward:240.0, Avg Reward: 221.18
# Episode 10800, Current Reward:219.0, Avg Reward: 231.04
# to save model and avg_rewards 316
# Episode 10850, Current Reward:222.0, Avg Reward: 222.84
# Episode 10900, Current Reward:153.0, Avg Reward: 229.3
# Episode 10950, Current Reward:274.0, Avg Reward: 235.5
# Episode 11000, Current Reward:209.0, Avg Reward: 238.54
# to save model and avg_rewards 320
# Episode 11050, Current Reward:180.0, Avg Reward: 237.34
# Episode 11100, Current Reward:230.0, Avg Reward: 244.88
# Episode 11150, Current Reward:232.0, Avg Reward: 250.36
# Episode 11200, Current Reward:200.0, Avg Reward: 251.3
# to save model and avg_rewards 324
# Episode 11250, Current Reward:221.0, Avg Reward: 243.46
# Episode 11300, Current Reward:214.0, Avg Reward: 250.52
# Episode 11350, Current Reward:300.0, Avg Reward: 251.02
# Episode 11400, Current Reward:231.0, Avg Reward: 253.42
# to save model and avg_rewards 328
# Episode 11450, Current Reward:289.0, Avg Reward: 278.26
# Episode 11500, Current Reward:286.0, Avg Reward: 250.74
# Episode 11550, Current Reward:284.0, Avg Reward: 250.78
# Episode 11600, Current Reward:312.0, Avg Reward: 252.04
# to save model and avg_rewards 332
# Episode 11650, Current Reward:297.0, Avg Reward: 278.08
# Episode 11700, Current Reward:498.0, Avg Reward: 291.58
# Episode 11750, Current Reward:176.0, Avg Reward: 268.38
# Episode 11800, Current Reward:249.0, Avg Reward: 265.98
# to save model and avg_rewards 336
# Episode 11850, Current Reward:368.0, Avg Reward: 284.88
# Episode 11900, Current Reward:197.0, Avg Reward: 287.98
# Episode 11950, Current Reward:293.0, Avg Reward: 274.22
# Episode 12000, Current Reward:384.0, Avg Reward: 297.48
# to save model and avg_rewards 340
# Episode 12050, Current Reward:195.0, Avg Reward: 273.5
# Episode 12100, Current Reward:399.0, Avg Reward: 304.7
# Episode 12150, Current Reward:199.0, Avg Reward: 287.26
# Episode 12200, Current Reward:291.0, Avg Reward: 296.14
# to save model and avg_rewards 344
# Episode 12250, Current Reward:265.0, Avg Reward: 308.94
# Episode 12300, Current Reward:318.0, Avg Reward: 311.92
# Episode 12350, Current Reward:272.0, Avg Reward: 313.58
# Episode 12400, Current Reward:419.0, Avg Reward: 320.56
# to save model and avg_rewards 348
# Episode 12450, Current Reward:243.0, Avg Reward: 322.64
# Episode 12500, Current Reward:270.0, Avg Reward: 303.6
# Episode 12550, Current Reward:219.0, Avg Reward: 274.76
# Episode 12600, Current Reward:471.0, Avg Reward: 288.42
# to save model and avg_rewards 352
# Episode 12650, Current Reward:323.0, Avg Reward: 309.68
# Episode 12700, Current Reward:423.0, Avg Reward: 332.88
# Episode 12750, Current Reward:265.0, Avg Reward: 337.22
# Episode 12800, Current Reward:295.0, Avg Reward: 335.2
# to save model and avg_rewards 356
# Episode 12850, Current Reward:247.0, Avg Reward: 333.04
# Episode 12900, Current Reward:290.0, Avg Reward: 339.66
# Episode 12950, Current Reward:420.0, Avg Reward: 351.28
# Episode 13000, Current Reward:315.0, Avg Reward: 316.22
# to save model and avg_rewards 360
# Episode 13050, Current Reward:266.0, Avg Reward: 323.44
# Episode 13100, Current Reward:350.0, Avg Reward: 339.6
# Episode 13150, Current Reward:343.0, Avg Reward: 333.7
# Episode 13200, Current Reward:325.0, Avg Reward: 324.14
# to save model and avg_rewards 364
# Episode 13250, Current Reward:218.0, Avg Reward: 300.74
# Episode 13300, Current Reward:394.0, Avg Reward: 260.76
# Episode 13350, Current Reward:268.0, Avg Reward: 273.94
# Episode 13400, Current Reward:261.0, Avg Reward: 262.46
# to save model and avg_rewards 368
# Episode 13450, Current Reward:208.0, Avg Reward: 309.16
# Episode 13500, Current Reward:285.0, Avg Reward: 285.84
# Episode 13550, Current Reward:500.0, Avg Reward: 318.32
# Episode 13600, Current Reward:324.0, Avg Reward: 295.12
# to save model and avg_rewards 372
# Episode 13650, Current Reward:325.0, Avg Reward: 293.06
# Episode 13700, Current Reward:249.0, Avg Reward: 305.98
# Episode 13750, Current Reward:231.0, Avg Reward: 281.62
# Episode 13800, Current Reward:247.0, Avg Reward: 318.22
# to save model and avg_rewards 376
# Episode 13850, Current Reward:464.0, Avg Reward: 276.22
# Episode 13900, Current Reward:234.0, Avg Reward: 311.84
# Episode 13950, Current Reward:228.0, Avg Reward: 269.48
# Episode 14000, Current Reward:255.0, Avg Reward: 271.56
# to save model and avg_rewards 380
# Episode 14050, Current Reward:234.0, Avg Reward: 283.62
# Episode 14100, Current Reward:243.0, Avg Reward: 252.56
# Episode 14150, Current Reward:445.0, Avg Reward: 272.42
# Episode 14200, Current Reward:270.0, Avg Reward: 280.02
# to save model and avg_rewards 384
# Episode 14250, Current Reward:249.0, Avg Reward: 272.1
# Episode 14300, Current Reward:326.0, Avg Reward: 289.18
# Episode 14350, Current Reward:242.0, Avg Reward: 298.6
# Episode 14400, Current Reward:309.0, Avg Reward: 264.76
# to save model and avg_rewards 388
# Episode 14450, Current Reward:391.0, Avg Reward: 299.28
# Episode 14500, Current Reward:264.0, Avg Reward: 283.04
# Episode 14550, Current Reward:224.0, Avg Reward: 294.7
# Episode 14600, Current Reward:219.0, Avg Reward: 286.56
# to save model and avg_rewards 392
# Episode 14650, Current Reward:240.0, Avg Reward: 238.62
# Episode 14700, Current Reward:246.0, Avg Reward: 259.6
# Episode 14750, Current Reward:228.0, Avg Reward: 255.46
# Episode 14800, Current Reward:256.0, Avg Reward: 257.12
# to save model and avg_rewards 396
# Episode 14850, Current Reward:260.0, Avg Reward: 289.5
# Episode 14900, Current Reward:291.0, Avg Reward: 253.56
# Episode 14950, Current Reward:306.0, Avg Reward: 259.4
# Episode 15000, Current Reward:263.0, Avg Reward: 261.98
# to save model and avg_rewards 400
# Episode 15050, Current Reward:289.0, Avg Reward: 253.32
# Episode 15100, Current Reward:268.0, Avg Reward: 304.58
# Episode 15150, Current Reward:291.0, Avg Reward: 260.98
# Episode 15200, Current Reward:229.0, Avg Reward: 260.9
# to save model and avg_rewards 404
# Episode 15250, Current Reward:192.0, Avg Reward: 290.38
# Episode 15300, Current Reward:251.0, Avg Reward: 235.68
# Episode 15350, Current Reward:205.0, Avg Reward: 257.68
# Episode 15400, Current Reward:315.0, Avg Reward: 251.56
# to save model and avg_rewards 408
# Episode 15450, Current Reward:224.0, Avg Reward: 248.84
# Episode 15500, Current Reward:288.0, Avg Reward: 257.36
# Episode 15550, Current Reward:240.0, Avg Reward: 268.18
# Episode 15600, Current Reward:249.0, Avg Reward: 275.16
# to save model and avg_rewards 412
# Episode 15650, Current Reward:263.0, Avg Reward: 281.54
# Episode 15700, Current Reward:204.0, Avg Reward: 261.38
# Episode 15750, Current Reward:265.0, Avg Reward: 284.2
# Episode 15800, Current Reward:238.0, Avg Reward: 266.68
# to save model and avg_rewards 416
# Episode 15850, Current Reward:228.0, Avg Reward: 268.46
# Episode 15900, Current Reward:235.0, Avg Reward: 284.4
# Episode 15950, Current Reward:301.0, Avg Reward: 263.42
# Episode 16000, Current Reward:191.0, Avg Reward: 245.72
# to save model and avg_rewards 420
# Episode 16050, Current Reward:310.0, Avg Reward: 256.96
# Episode 16100, Current Reward:227.0, Avg Reward: 259.76
# Episode 16150, Current Reward:254.0, Avg Reward: 257.94
# Episode 16200, Current Reward:237.0, Avg Reward: 273.02
# to save model and avg_rewards 424
# Episode 16250, Current Reward:281.0, Avg Reward: 257.64
# Episode 16300, Current Reward:243.0, Avg Reward: 249.8
# Episode 16350, Current Reward:216.0, Avg Reward: 259.06
# Episode 16400, Current Reward:225.0, Avg Reward: 247.28
# to save model and avg_rewards 428
# Episode 16450, Current Reward:342.0, Avg Reward: 274.5
# Episode 16500, Current Reward:221.0, Avg Reward: 255.28
# Episode 16550, Current Reward:303.0, Avg Reward: 246.54
# Episode 16600, Current Reward:271.0, Avg Reward: 264.08
# to save model and avg_rewards 432
# Episode 16650, Current Reward:294.0, Avg Reward: 260.04
# Episode 16700, Current Reward:239.0, Avg Reward: 249.5
# Episode 16750, Current Reward:253.0, Avg Reward: 262.12
# Episode 16800, Current Reward:205.0, Avg Reward: 270.24
# to save model and avg_rewards 436
# Episode 16850, Current Reward:374.0, Avg Reward: 277.84
# Episode 16900, Current Reward:195.0, Avg Reward: 261.44
# Episode 16950, Current Reward:209.0, Avg Reward: 256.0
# Episode 17000, Current Reward:204.0, Avg Reward: 262.44
# to save model and avg_rewards 440
# Episode 17050, Current Reward:236.0, Avg Reward: 257.02
# Episode 17100, Current Reward:222.0, Avg Reward: 249.32
# Episode 17150, Current Reward:183.0, Avg Reward: 246.08
# Episode 17200, Current Reward:187.0, Avg Reward: 236.54
# to save model and avg_rewards 444
# Episode 17250, Current Reward:218.0, Avg Reward: 227.08
# Episode 17300, Current Reward:252.0, Avg Reward: 245.8
# Episode 17350, Current Reward:277.0, Avg Reward: 239.84
# Episode 17400, Current Reward:266.0, Avg Reward: 233.74
# to save model and avg_rewards 448
# Episode 17450, Current Reward:217.0, Avg Reward: 258.76
# Episode 17500, Current Reward:337.0, Avg Reward: 255.96
# Episode 17550, Current Reward:226.0, Avg Reward: 243.84
# Episode 17600, Current Reward:258.0, Avg Reward: 263.62
# to save model and avg_rewards 452
# Episode 17650, Current Reward:335.0, Avg Reward: 233.52
# Episode 17700, Current Reward:235.0, Avg Reward: 235.7
# Episode 17750, Current Reward:216.0, Avg Reward: 244.4
# Episode 17800, Current Reward:205.0, Avg Reward: 228.72
# to save model and avg_rewards 456
# Episode 17850, Current Reward:202.0, Avg Reward: 237.48
# Episode 17900, Current Reward:275.0, Avg Reward: 235.82
# Episode 17950, Current Reward:239.0, Avg Reward: 230.86
# Episode 18000, Current Reward:237.0, Avg Reward: 226.7
# to save model and avg_rewards 460
# Episode 18050, Current Reward:300.0, Avg Reward: 232.98
# Episode 18100, Current Reward:206.0, Avg Reward: 213.94
# Episode 18150, Current Reward:205.0, Avg Reward: 218.12
# Episode 18200, Current Reward:218.0, Avg Reward: 228.9
# to save model and avg_rewards 464
# Episode 18250, Current Reward:224.0, Avg Reward: 224.3
# Episode 18300, Current Reward:243.0, Avg Reward: 220.58
# Episode 18350, Current Reward:269.0, Avg Reward: 235.06
# Episode 18400, Current Reward:229.0, Avg Reward: 231.14
# to save model and avg_rewards 468
# Episode 18450, Current Reward:226.0, Avg Reward: 224.06
# Episode 18500, Current Reward:231.0, Avg Reward: 254.4
# Episode 18550, Current Reward:195.0, Avg Reward: 252.5
# Episode 18600, Current Reward:339.0, Avg Reward: 250.34
# to save model and avg_rewards 472
# Episode 18650, Current Reward:339.0, Avg Reward: 244.82
# Episode 18700, Current Reward:220.0, Avg Reward: 253.24
# Episode 18750, Current Reward:208.0, Avg Reward: 249.0
# Episode 18800, Current Reward:251.0, Avg Reward: 242.58
# to save model and avg_rewards 476
# Episode 18850, Current Reward:305.0, Avg Reward: 241.88
# Episode 18900, Current Reward:209.0, Avg Reward: 249.92
# Episode 18950, Current Reward:290.0, Avg Reward: 246.82
# Episode 19000, Current Reward:199.0, Avg Reward: 232.84
# to save model and avg_rewards 480
# Episode 19050, Current Reward:248.0, Avg Reward: 251.2
# Episode 19100, Current Reward:179.0, Avg Reward: 239.12
# Episode 19150, Current Reward:273.0, Avg Reward: 232.46
# Episode 19200, Current Reward:253.0, Avg Reward: 246.18
# to save model and avg_rewards 484
# Episode 19250, Current Reward:288.0, Avg Reward: 238.6
# Episode 19300, Current Reward:225.0, Avg Reward: 238.76
# Episode 19350, Current Reward:232.0, Avg Reward: 262.46
# Episode 19400, Current Reward:244.0, Avg Reward: 235.7
# to save model and avg_rewards 488
# Episode 19450, Current Reward:214.0, Avg Reward: 225.3
# Episode 19500, Current Reward:243.0, Avg Reward: 248.8
# Episode 19550, Current Reward:215.0, Avg Reward: 241.64
# Episode 19600, Current Reward:251.0, Avg Reward: 240.28
# to save model and avg_rewards 492
# Episode 19650, Current Reward:291.0, Avg Reward: 257.26
# Episode 19700, Current Reward:248.0, Avg Reward: 247.02
# Episode 19750, Current Reward:223.0, Avg Reward: 244.22
# Episode 19800, Current Reward:248.0, Avg Reward: 251.02
# to save model and avg_rewards 496
# Episode 19850, Current Reward:225.0, Avg Reward: 249.22
# Episode 19900, Current Reward:197.0, Avg Reward: 244.8
# Episode 19950, Current Reward:188.0, Avg Reward: 248.6
# Episode 20000, Current Reward:233.0, Avg Reward: 234.3
# to save model and avg_rewards 500

# %%
# 绘制得分变化图
plt.plot(range(1, len(avg_rewards) + 1), avg_rewards)
plt.xlabel("Episode")
plt.ylabel("Avg Reward")
plt.title(f"Avg Reward over Episodes x{avg_episode}")
plt.show()
